# %% [markdown]
# <a href="https://colab.research.google.com/github/P-12/Orbyts-2026/blob/main/Copy_of_tutorial_desispec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial: DESI spectral fitting with `provabgs`

# %% [markdown]
# Copy of the tutorial from provabgs. First we install the relevant libraries

# %%
# lets install the python package `provabgs`, a python package for generating the PRObabilistic Value-Added BGS (PROVABGS)
# !pip install git+https://github.com/changhoonhahn/provabgs.git --upgrade --user
# !pip install fitsio
# !pip install desispec
# Out:
# Collecting git+https://github.com/changhoonhahn/provabgs.git
#   Cloning https://github.com/changhoonhahn/provabgs.git to /tmp/pip-req-build-8bi7sgbs
#   Running command git clone --filter=blob:none --quiet https://github.com/changhoonhahn/provabgs.git /tmp/pip-req-build-8bi7sgbs
#   Resolved https://github.com/changhoonhahn/provabgs.git to commit f192008df8a03cfbdbb35d1b0128def4c1424752
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>1.18 in /usr/local/lib/python3.12/dist-packages (from provabgs==0.1) (2.0.2)
# Requirement already satisfied: h5py>=2.10 in /usr/local/lib/python3.12/dist-packages (from provabgs==0.1) (3.15.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from provabgs==0.1) (0.60.0)
# Requirement already satisfied: speclite in /root/.local/lib/python3.12/site-packages (from provabgs==0.1) (0.20)
# Requirement already satisfied: zeus-mcmc in /root/.local/lib/python3.12/site-packages (from provabgs==0.1) (2.5.4)
# Requirement already satisfied: emcee in /root/.local/lib/python3.12/site-packages (from provabgs==0.1) (3.1.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->provabgs==0.1) (0.43.0)
# Requirement already satisfied: astropy in /usr/local/lib/python3.12/dist-packages (from speclite->provabgs==0.1) (7.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from speclite->provabgs==0.1) (1.16.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from speclite->provabgs==0.1) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc->provabgs==0.1) (4.67.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc->provabgs==0.1) (75.2.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc->provabgs==0.1) (8.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc->provabgs==0.1) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc->provabgs==0.1) (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc->provabgs==0.1) (1.6.1)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy->speclite->provabgs==0.1) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /usr/local/lib/python3.12/dist-packages (from astropy->speclite->provabgs==0.1) (0.2026.2.9.0.50.33)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy->speclite->provabgs==0.1) (26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc->provabgs==0.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc->provabgs==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc->provabgs==0.1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc->provabgs==0.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc->provabgs==0.1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc->provabgs==0.1) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc->provabgs==0.1) (2.9.0.post0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->zeus-mcmc->provabgs==0.1) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->zeus-mcmc->provabgs==0.1) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->zeus-mcmc->provabgs==0.1) (2.19.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->zeus-mcmc->provabgs==0.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->zeus-mcmc->provabgs==0.1) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn->zeus-mcmc->provabgs==0.1) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->zeus-mcmc->provabgs==0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->zeus-mcmc->provabgs==0.1) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->zeus-mcmc->provabgs==0.1) (1.17.0)
# Requirement already satisfied: fitsio in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.12/dist-packages (from fitsio) (2.0.2)
# Requirement already satisfied: desispec in /usr/local/lib/python3.12/dist-packages (0.70.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from desispec) (2025.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from desispec) (2.32.4)
# Requirement already satisfied: astropy in /usr/local/lib/python3.12/dist-packages (from desispec) (7.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from desispec) (1.16.3)
# Requirement already satisfied: fitsio in /usr/local/lib/python3.12/dist-packages (from desispec) (1.3.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from desispec) (0.60.0)
# Requirement already satisfied: healpy in /usr/local/lib/python3.12/dist-packages (from desispec) (1.19.0)
# Requirement already satisfied: speclite in /root/.local/lib/python3.12/site-packages (from desispec) (0.20)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (from desispec) (2.0.46)
# Requirement already satisfied: desiutil in /usr/local/lib/python3.12/dist-packages (from desispec) (3.6.0)
# Requirement already satisfied: desitarget in /usr/local/lib/python3.12/dist-packages (from desispec) (4.4.0)
# Requirement already satisfied: desimodel in /usr/local/lib/python3.12/dist-packages (from desispec) (0.20.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from astropy->desispec) (2.0.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy->desispec) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /usr/local/lib/python3.12/dist-packages (from astropy->desispec) (0.2026.2.9.0.50.33)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy->desispec) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy->desispec) (26.0)
# Requirement already satisfied: configobj in /usr/local/lib/python3.12/dist-packages (from desimodel->desispec) (5.0.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from desimodel->desispec) (3.10.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->desispec) (0.43.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->desispec) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->desispec) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->desispec) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->desispec) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->desispec) (3.3.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->desispec) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->desimodel->desispec) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->desimodel->desispec) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->desimodel->desispec) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->desimodel->desispec) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->desimodel->desispec) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->desimodel->desispec) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->desimodel->desispec) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->desimodel->desispec) (1.17.0)

# %%
import os
os.environ['PATH'] += '/root/.local/bin'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install zeus-mcmc --user
# !export SPS_HOME="/content/python-fsps"
# !git clone --recursive https://github.com/dfm/python-fsps.git $SPS_HOME
# !python -m pip install /content/python-fsps
# Out:
# Requirement already satisfied: zeus-mcmc in /root/.local/lib/python3.12/site-packages (2.5.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc) (4.67.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc) (75.2.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc) (8.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc) (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from zeus-mcmc) (1.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->zeus-mcmc) (2.9.0.post0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->zeus-mcmc) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->zeus-mcmc) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->zeus-mcmc) (2.19.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->zeus-mcmc) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->zeus-mcmc) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn->zeus-mcmc) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->zeus-mcmc) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->zeus-mcmc) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->zeus-mcmc) (1.17.0)
# Processing ./python-fsps
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from fsps==0.4.8.dev81+g02e202b7e) (2.0.2)
# Building wheels for collected packages: fsps
#   Building wheel for fsps (pyproject.toml) ... done
#   Created wheel for fsps: filename=fsps-0.4.8.dev81+g02e202b7e-cp312-cp312-linux_x86_64.whl size=249304 sha256=5b165c7c383face97ae4d0d22b9755b9abf47afb28fc7c2b2235f60d84ab3d76
#   Stored in directory: /root/.cache/pip/wheels/08/3e/c8/9b9a61a59a94d1ed312d894993627eb8b13f9f55ff68f35e50
# Successfully built fsps
# Installing collected packages: fsps
#   Attempting uninstall: fsps
#     Found existing installation: fsps 0.4.7
#     Uninstalling fsps-0.4.7:
#       Successfully uninstalled fsps-0.4.7
# Successfully installed fsps-0.4.8.dev81+g02e202b7e

# %%
import numpy as np

# %% [markdown]
# Check that desispect, fitsio, fsps and provabgs are properly installed by listing all the libraries available

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------------
# absl-py                                  1.4.0
# accelerate                               1.12.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.3
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.4
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.12.1
# anywidget                                0.9.21
# apsw                                     3.51.2.0
# apswutils                                0.1.2
# argon2-cffi                              25.1.0
# argon2-cffi-bindings                     25.1.0
# array_record                             0.8.3
# arrow                                    1.4.0
# arviz                                    0.22.0
# astropy                                  7.2.0
# astropy-iers-data                        0.2026.2.9.0.50.33
# astunparse                               1.6.3
# atpublic                                 5.1
# attrs                                    25.4.0
# audioread                                3.1.0
# Authlib                                  1.6.7
# autograd                                 1.8.0
# babel                                    2.18.0
# backcall                                 0.2.0
# beartype                                 0.22.9
# beautifulsoup4                           4.13.5
# betterproto                              2.0.0b6
# bigframes                                2.33.0
# bigquery-magics                          0.12.0
# bleach                                   6.3.0
# blinker                                  1.9.0
# blis                                     1.3.3
# blobfile                                 3.2.0
# blosc2                                   4.0.0
# bokeh                                    3.7.3
# Bottleneck                               1.4.2
# bqplot                                   0.12.45
# branca                                   0.8.2
# brotli                                   1.2.0
# CacheControl                             0.14.4
# cachetools                               7.0.1
# catalogue                                2.0.10
# certifi                                  2026.1.4
# cffi                                     2.0.0
# chardet                                  5.2.0
# charset-normalizer                       3.4.4
# clarabel                                 0.11.1
# click                                    8.3.1
# click-plugins                            1.1.1.2
# cligj                                    0.7.2
# cloudpathlib                             0.23.0
# cloudpickle                              3.1.2
# cmake                                    3.31.10
# cmdstanpy                                1.3.0
# colorcet                                 3.1.0
# colorlover                               0.3.0
# colour                                   0.1.5
# community                                1.0.0b1
# confection                               0.1.5
# configobj                                5.0.9
# cons                                     0.4.7
# contourpy                                1.3.3
# cramjam                                  2.11.0
# cryptography                             43.0.3
# cufflinks                                0.17.3
# curl_cffi                                0.14.0
# cvxopt                                   1.3.2
# cvxpy                                    1.6.7
# cycler                                   0.12.1
# cyipopt                                  1.5.0
# cymem                                    2.0.13
# Cython                                   3.0.12
# dask                                     2025.12.0
# dataproc-spark-connect                   1.0.2
# datasets                                 4.0.0
# db-dtypes                                1.5.0
# dbus-python                              1.2.18
# debugpy                                  1.8.15
# decorator                                4.4.2
# defusedxml                               0.7.1
# deprecation                              2.1.0
# desimodel                                0.20.0
# desispec                                 0.70.0
# desitarget                               4.4.0
# desiutil                                 3.6.0
# diffusers                                0.36.0
# dill                                     0.3.8
# distro                                   1.9.0
# dlib                                     19.24.6
# dm-tree                                  0.1.9
# docstring_parser                         0.17.0
# docutils                                 0.21.2
# dopamine_rl                              4.1.2
# duckdb                                   1.3.2
# earthengine-api                          1.5.24
# easydict                                 1.13
# editdistance                             0.8.1
# eerepr                                   0.1.2
# einops                                   0.8.2
# emcee                                    3.1.6
# en_core_web_sm                           3.8.0
# entrypoints                              0.4
# esda                                     2.8.1
# et_xmlfile                               2.0.0
# etils                                    1.13.0
# etuples                                  0.3.10
# Farama-Notifications                     0.0.4
# fastai                                   2.8.6
# fastapi                                  0.129.0
# fastcore                                 1.12.13
# fastdownload                             0.0.7
# fastjsonschema                           2.21.2
# fastlite                                 0.2.4
# fastprogress                             1.1.3
# fasttransform                            0.0.2
# ffmpy                                    1.0.0
# filelock                                 3.21.0
# fiona                                    1.10.1
# firebase-admin                           6.9.0
# fitsio                                   1.3.0
# Flask                                    3.1.2
# flatbuffers                              25.12.19
# flax                                     0.11.2
# folium                                   0.20.0
# fonttools                                4.61.1
# fqdn                                     1.5.1
# frozendict                               2.4.7
# frozenlist                               1.8.0
# fsps                                     0.4.7
# fsspec                                   2025.3.0
# future                                   1.0.0
# gast                                     0.7.0
# gcsfs                                    2025.3.0
# GDAL                                     3.8.4
# gdown                                    5.2.1
# geemap                                   0.35.3
# geocoder                                 1.38.1
# geographiclib                            2.1
# geopandas                                1.1.2
# geopy                                    2.4.1
# giddy                                    2.3.8
# gin-config                               0.5.0
# gitdb                                    4.0.12
# GitPython                                3.1.46
# glob2                                    0.7
# google                                   3.0.0
# google-adk                               1.25.0
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.29.0
# google-api-python-client                 2.190.0
# google-auth                              2.47.0
# google-auth-httplib2                     0.3.0
# google-auth-oauthlib                     1.2.4
# google-cloud-aiplatform                  1.137.0
# google-cloud-appengine-logging           1.8.0
# google-cloud-audit-log                   0.4.0
# google-cloud-bigquery                    3.40.1
# google-cloud-bigquery-connection         1.20.0
# google-cloud-bigquery-storage            2.36.1
# google-cloud-bigtable                    2.35.0
# google-cloud-core                        2.5.0
# google-cloud-dataproc                    5.24.0
# google-cloud-datastore                   2.23.0
# google-cloud-discoveryengine             0.13.12
# google-cloud-firestore                   2.23.0
# google-cloud-functions                   1.22.0
# google-cloud-iam                         2.21.0
# google-cloud-language                    2.19.0
# google-cloud-logging                     3.13.0
# google-cloud-monitoring                  2.29.1
# google-cloud-pubsub                      2.35.0
# google-cloud-resource-manager            1.16.0
# google-cloud-secret-manager              2.26.0
# google-cloud-spanner                     3.62.0
# google-cloud-speech                      2.36.1
# google-cloud-storage                     3.9.0
# google-cloud-trace                       1.18.0
# google-cloud-translate                   3.24.0
# google-colab                             1.0.0
# google-crc32c                            1.8.0
# google-genai                             1.63.0
# google-generativeai                      0.8.6
# google-pasta                             0.2.0
# google-resumable-media                   2.8.0
# googleapis-common-protos                 1.72.0
# googledrivedownloader                    1.1.0
# gradio                                   5.50.0
# gradio_client                            1.14.0
# grain                                    0.2.15
# graphviz                                 0.21
# greenlet                                 3.3.1
# groovy                                   0.1.2
# grpc-google-iam-v1                       0.14.3
# grpc-interceptor                         0.15.4
# grpcio                                   1.78.0
# grpcio-status                            1.71.2
# grpclib                                  0.4.9
# gspread                                  6.2.1
# gspread-dataframe                        4.0.0
# gym                                      0.25.2
# gym-notices                              0.1.0
# gymnasium                                1.2.3
# h11                                      0.16.0
# h2                                       4.3.0
# h5netcdf                                 1.8.1
# h5py                                     3.15.1
# hdbscan                                  0.8.41
# healpy                                   1.19.0
# hf-xet                                   1.2.0
# highspy                                  1.13.1
# holidays                                 0.90
# holoviews                                1.22.1
# hpack                                    4.1.0
# html5lib                                 1.1
# httpcore                                 1.0.9
# httpimport                               1.4.1
# httplib2                                 0.31.2
# httptools                                0.7.1
# httpx                                    0.28.1
# httpx-sse                                0.4.3
# huggingface_hub                          1.4.1
# humanize                                 4.15.0
# hyperframe                               6.1.0
# hyperopt                                 0.2.7
# ibis-framework                           9.5.0
# idna                                     3.11
# ImageIO                                  2.37.2
# imageio-ffmpeg                           0.6.0
# imagesize                                1.4.1
# imbalanced-learn                         0.14.1
# immutabledict                            4.3.0
# importlib_metadata                       8.7.1
# importlib_resources                      6.5.2
# imutils                                  0.5.4
# inequality                               1.1.2
# inflect                                  7.5.0
# iniconfig                                2.3.0
# intel-cmplr-lib-ur                       2025.3.2
# intel-openmp                             2025.3.2
# ipyevents                                2.0.4
# ipyfilechooser                           0.6.0
# ipykernel                                6.17.1
# ipyleaflet                               0.20.0
# ipyparallel                              8.8.0
# ipython                                  7.34.0
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipytree                                  0.2.2
# ipywidgets                               7.7.1
# isoduration                              20.11.0
# itsdangerous                             2.2.0
# jaraco.classes                           3.4.0
# jaraco.context                           6.1.0
# jaraco.functools                         4.4.0
# jax                                      0.7.2
# jaxlib                                   0.7.2
# jeepney                                  0.9.0
# jieba                                    0.42.1
# Jinja2                                   3.1.6
# jiter                                    0.13.0
# joblib                                   1.5.3
# jsonpatch                                1.33
# jsonpickle                               4.1.1
# jsonpointer                              3.0.0
# jsonschema                               4.26.0
# jsonschema-specifications                2025.9.1
# jupyter_client                           7.4.9
# jupyter-console                          6.6.3
# jupyter_core                             5.9.1
# jupyter-events                           0.12.0
# jupyter_kernel_gateway                   2.5.2
# jupyter-leaflet                          0.20.0
# jupyter_server                           2.14.0
# jupyter_server_terminals                 0.5.4
# jupyterlab_pygments                      0.3.0
# jupyterlab_widgets                       3.0.16
# jupytext                                 1.19.1
# kaggle                                   1.7.4.5
# kagglehub                                0.3.13
# keras                                    3.10.0
# keras-hub                                0.21.1
# keras-nlp                                0.21.1
# keyring                                  25.7.0
# keyrings.google-artifactregistry-auth    1.1.2
# kiwisolver                               1.4.9
# langchain                                1.2.10
# langchain-core                           1.2.12
# langgraph                                1.0.8
# langgraph-checkpoint                     4.0.0
# langgraph-prebuilt                       1.0.7
# langgraph-sdk                            0.3.5
# langsmith                                0.7.1
# lark                                     1.3.1
# launchpadlib                             1.10.16
# lazr.restfulclient                       0.14.4
# lazr.uri                                 1.0.6
# lazy_loader                              0.4
# libclang                                 18.1.1
# libpysal                                 4.14.1
# librosa                                  0.11.0
# lightgbm                                 4.6.0
# linkify-it-py                            2.0.3
# llvmlite                                 0.43.0
# locket                                   1.0.0
# logical-unification                      0.4.7
# lxml                                     6.0.2
# Mako                                     1.3.10
# mapclassify                              2.10.0
# Markdown                                 3.10.2
# markdown-it-py                           4.0.0
# MarkupSafe                               3.0.3
# matplotlib                               3.10.0
# matplotlib-inline                        0.2.1
# matplotlib-venn                          1.1.2
# mcp                                      1.26.0
# mdit-py-plugins                          0.5.0
# mdurl                                    0.1.2
# mgwr                                     2.2.1
# miniKanren                               1.0.5
# missingno                                0.5.2
# mistune                                  3.2.0
# mizani                                   0.13.5
# mkl                                      2025.3.1
# ml_dtypes                                0.5.4
# mlxtend                                  0.23.4
# mmh3                                     5.2.0
# momepy                                   0.11.0
# more-itertools                           10.8.0
# moviepy                                  1.0.3
# mpmath                                   1.3.0
# msgpack                                  1.1.2
# multidict                                6.7.1
# multipledispatch                         1.0.0
# multiprocess                             0.70.16
# multitasking                             0.0.12
# murmurhash                               1.0.15
# music21                                  9.9.1
# namex                                    0.1.0
# narwhals                                 2.16.0
# natsort                                  8.4.0
# nbclassic                                1.3.3
# nbclient                                 0.10.4
# nbconvert                                7.17.0
# nbformat                                 5.10.4
# ndindex                                  1.10.1
# nest-asyncio                             1.6.0
# networkx                                 3.6.1
# nibabel                                  5.3.3
# nltk                                     3.9.1
# notebook                                 6.5.7
# notebook_shim                            0.2.4
# numba                                    0.60.0
# numexpr                                  2.14.1
# numpy                                    2.0.2
# nvidia-nccl-cu12                         2.29.3
# oauth2client                             4.1.3
# oauthlib                                 3.3.1
# omegaconf                                2.3.0
# onemkl-license                           2025.3.1
# openai                                   2.20.0
# opencv-contrib-python                    4.13.0.92
# opencv-python                            4.13.0.92
# opencv-python-headless                   4.13.0.92
# openpyxl                                 3.1.5
# opentelemetry-api                        1.38.0
# opentelemetry-exporter-gcp-logging       1.11.0a0
# opentelemetry-exporter-gcp-monitoring    1.11.0a0
# opentelemetry-exporter-gcp-trace         1.11.0
# opentelemetry-exporter-otlp-proto-common 1.38.0
# opentelemetry-exporter-otlp-proto-http   1.38.0
# opentelemetry-proto                      1.38.0
# opentelemetry-resourcedetector-gcp       1.11.0a0
# opentelemetry-sdk                        1.38.0
# opentelemetry-semantic-conventions       0.59b0
# opt_einsum                               3.4.0
# optax                                    0.2.7
# optree                                   0.18.0
# orbax-checkpoint                         0.11.32
# orjson                                   3.11.7
# ormsgpack                                1.12.2
# osqp                                     1.1.1
# overrides                                7.7.0
# packaging                                26.0
# pandas                                   2.2.2
# pandas-datareader                        0.10.0
# pandas-gbq                               0.30.0
# pandas-stubs                             2.2.2.240909
# pandocfilters                            1.5.1
# panel                                    1.8.7
# param                                    2.3.2
# parso                                    0.8.6
# parsy                                    2.2
# partd                                    1.4.2
# patsy                                    1.0.2
# peewee                                   3.19.0
# peft                                     0.18.1
# pexpect                                  4.9.0
# pickleshare                              0.7.5
# pillow                                   11.3.0
# pip                                      24.1.2
# platformdirs                             4.6.0
# plotly                                   5.24.1
# plotnine                                 0.14.5
# pluggy                                   1.6.0
# plum-dispatch                            2.6.1
# ply                                      3.11
# pointpats                                2.5.2
# polars                                   1.31.0
# pooch                                    1.9.0
# portpicker                               1.5.2
# preshed                                  3.0.12
# prettytable                              3.17.0
# proglog                                  0.1.12
# progressbar2                             4.5.0
# prometheus_client                        0.24.1
# promise                                  2.3
# prompt_toolkit                           3.0.52
# propcache                                0.4.1
# prophet                                  1.3.0
# proto-plus                               1.27.1
# protobuf                                 5.29.6
# provabgs                                 0.1
# psutil                                   5.9.5
# psycopg2                                 2.9.11
# psygnal                                  0.15.1
# ptyprocess                               0.7.0
# PuLP                                     3.3.0
# py-cpuinfo                               9.0.0
# py4j                                     0.10.9.9
# pyarrow                                  18.1.0
# pyasn1                                   0.6.2
# pyasn1_modules                           0.4.2
# pycairo                                  1.29.0
# pycocotools                              2.0.11
# pycparser                                3.0
# pycryptodomex                            3.23.0
# pydantic                                 2.12.3
# pydantic_core                            2.41.4
# pydantic-settings                        2.12.0
# pydata-google-auth                       1.9.1
# pydot                                    4.0.1
# pydotplus                                2.0.2
# PyDrive2                                 1.21.3
# pydub                                    0.25.1
# pyerfa                                   2.0.1.5
# pygame                                   2.6.1
# pygit2                                   1.19.1
# Pygments                                 2.19.2
# PyGObject                                3.48.2
# PyJWT                                    2.11.0
# pymc                                     5.27.1
# pynndescent                              0.6.0
# pyogrio                                  0.12.1
# pyomo                                    6.9.5
# PyOpenGL                                 3.1.10
# pyOpenSSL                                24.2.1
# pyparsing                                3.3.2
# pyperclip                                1.11.0
# pyproj                                   3.7.2
# pysal                                    25.7
# pyshp                                    3.0.3
# PySocks                                  1.7.1
# pyspark                                  4.0.2
# pytensor                                 2.37.0
# pytest                                   8.4.2
# python-apt                               0.0.0
# python-box                               7.3.2
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.2.1
# python-fasthtml                          0.12.41
# python-json-logger                       4.0.0
# python-louvain                           0.16
# python-multipart                         0.0.22
# python-slugify                           8.0.4
# python-snappy                            0.7.3
# python-utils                             3.9.1
# pytz                                     2025.2
# pyviz_comms                              3.0.6
# PyWavelets                               1.9.0
# PyYAML                                   6.0.3
# pyzmq                                    26.2.1
# quantecon                                0.10.1
# rasterio                                 1.5.0
# rasterstats                              0.20.0
# ratelim                                  0.1.6
# referencing                              0.37.0
# regex                                    2025.11.3
# requests                                 2.32.4
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# requirements-parser                      0.9.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rfc3987-syntax                           1.1.0
# rich                                     13.9.4
# roman-numerals                           4.1.0
# roman-numerals-py                        4.1.0
# rpds-py                                  0.30.0
# rpy2                                     3.5.17
# rsa                                      4.9.1
# rtree                                    1.4.1
# ruff                                     0.15.0
# safehttpx                                0.1.7
# safetensors                              0.7.0
# scikit-image                             0.25.2
# scikit-learn                             1.6.1
# scipy                                    1.16.3
# scooby                                   0.11.0
# scs                                      3.2.11
# seaborn                                  0.13.2
# SecretStorage                            3.5.0
# segregation                              2.5.3
# semantic-version                         2.10.0
# Send2Trash                               2.1.0
# sentence-transformers                    5.2.2
# sentencepiece                            0.2.1
# sentry-sdk                               2.52.0
# setuptools                               75.2.0
# shap                                     0.50.0
# shapely                                  2.1.2
# shellingham                              1.5.4
# simple-parsing                           0.1.8
# simplejson                               3.20.2
# simsimd                                  6.5.12
# six                                      1.17.0
# sklearn-compat                           0.1.5
# sklearn-pandas                           2.2.0
# slicer                                   0.0.8
# smart_open                               7.5.0
# smmap                                    5.0.2
# sniffio                                  1.3.1
# snowballstemmer                          3.0.1
# soundfile                                0.13.1
# soupsieve                                2.8.3
# soxr                                     1.0.0
# spacy                                    3.8.11
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# spaghetti                                1.7.6
# spanner-graph-notebook                   1.1.8
# speclite                                 0.20
# spglm                                    1.1.0
# Sphinx                                   8.2.3
# sphinxcontrib-applehelp                  2.0.0
# sphinxcontrib-devhelp                    2.0.0
# sphinxcontrib-htmlhelp                   2.1.0
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     2.0.0
# sphinxcontrib-serializinghtml            2.0.0
# spint                                    1.0.7
# splot                                    1.1.7
# spopt                                    0.7.0
# spreg                                    1.8.5
# SQLAlchemy                               2.0.46
# sqlalchemy-spanner                       1.17.2
# sqlglot                                  25.20.2
# sqlparse                                 0.5.5
# srsly                                    2.5.2
# sse-starlette                            3.2.0
# stanio                                   0.5.1
# starlette                                0.52.1
# statsmodels                              0.14.6
# stringzilla                              4.6.0
# stumpy                                   1.13.0
# sympy                                    1.14.0
# tables                                   3.10.2
# tabulate                                 0.9.0
# tbb                                      2022.3.1
# tcmlib                                   1.4.1
# tenacity                                 9.1.4
# tensorboard                              2.19.0
# tensorboard-data-server                  0.7.2
# tensorflow                               2.19.0
# tensorflow-datasets                      4.9.9
# tensorflow_decision_forests              1.12.0
# tensorflow-hub                           0.16.1
# tensorflow-metadata                      1.17.3
# tensorflow-probability                   0.25.0
# tensorflow-text                          2.19.0
# tensorstore                              0.1.81
# termcolor                                3.3.0
# terminado                                0.18.1
# text-unidecode                           1.3
# textblob                                 0.19.0
# tf_keras                                 2.19.0
# tf-slim                                  1.1.0
# thinc                                    8.3.10
# threadpoolctl                            3.6.0
# tifffile                                 2026.1.28
# tiktoken                                 0.12.0
# timm                                     1.0.24
# tinycss2                                 1.4.0
# tobler                                   0.13.0
# tokenizers                               0.22.2
# toml                                     0.10.2
# tomlkit                                  0.13.3
# toolz                                    0.12.1
# torch                                    2.9.0+cpu
# torchao                                  0.10.0
# torchaudio                               2.9.0+cpu
# torchcodec                               0.8.0
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.24.0+cpu
# tornado                                  6.5.1
# tqdm                                     4.67.3
# traitlets                                5.7.1
# traittypes                               0.2.3
# transformers                             5.0.0
# treescope                                0.1.10
# tsfresh                                  0.21.1
# tweepy                                   4.16.0
# typeguard                                4.4.4
# typer                                    0.23.0
# typer-slim                               0.23.0
# types-pytz                               2025.2.0.20251108
# types-setuptools                         80.9.0.20251223
# typing_extensions                        4.15.0
# typing-inspection                        0.4.2
# tzdata                                   2025.3
# tzlocal                                  5.3.1
# uc-micro-py                              1.0.3
# umap-learn                               0.5.11
# umf                                      1.0.3
# uri-template                             1.3.0
# uritemplate                              4.2.0
# urllib3                                  2.5.0
# uuid_utils                               0.14.0
# uvicorn                                  0.40.0
# uvloop                                   0.22.1
# vega-datasets                            0.9.0
# wadllib                                  1.3.6
# wandb                                    0.24.2
# wasabi                                   1.1.3
# watchdog                                 6.0.0
# watchfiles                               1.1.1
# wcwidth                                  0.6.0
# weasel                                   0.4.3
# webcolors                                25.10.0
# webencodings                             0.5.1
# websocket-client                         1.9.0
# websockets                               15.0.1
# Werkzeug                                 3.1.5
# wheel                                    0.46.3
# widgetsnbextension                       3.6.10
# wordcloud                                1.9.6
# wrapt                                    2.1.1
# wurlitzer                                3.1.1
# xarray                                   2025.12.0
# xarray-einstats                          0.9.1
# xgboost                                  3.2.0
# xlrd                                     2.0.2
# xxhash                                   3.6.0
# xyzservices                              2025.11.0
# yarl                                     1.22.0
# ydf                                      0.15.0
# yellowbrick                              1.5
# yfinance                                 0.2.66
# zeus-mcmc                                2.5.4
# zipp                                     3.23.0
# zstandard                                0.25.0

# %%
import os
os.environ["SPS_HOME"] = r'/content/python-fsps/src/fsps/libfsps'

# %%
from provabgs import infer as Infer
from provabgs import models as Models
from provabgs import flux_calib as FluxCalib

# %%
# -- plotting --
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['axes.xmargin'] = 1
mpl.rcParams['xtick.labelsize'] = 'x-large'
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['ytick.labelsize'] = 'x-large'
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['legend.frameon'] = False

# %% [markdown]
# The data isn't at the same location as in the PROVABGS tutorial, so make sure that 'coadd-0-80612-thru20201223.fits' is somewhere in your locally accessible files and point to that location.

# %%
# read in DESI Cascades spectra from TILE 80612
from desispec.io import read_spectra

spectra = read_spectra('/content/coadd-0-80612-thru20201223.fits')
# Out:
# INFO:spectra.py:453:read_spectra: iotime 0.772 sec to read spectra from:  coadd-0-80612-thru20201223.fits at 2026-02-18T16:14:30.900221
# INFO:desiutil.log.dlm58.info:iotime 0.772 sec to read spectra from:  coadd-0-80612-thru20201223.fits at 2026-02-18T16:14:30.900221

# %%
igal = 10

# %% [markdown]
# Now make sure you have 'zmtl-0-80612-thru20201223.fits' locally as well and point to the right location

# %%
from astropy.table import Table
zbest = Table.read('/content/zmtl-0-80612-thru20201223.fits', hdu=1)
zred = zbest['Z'][igal]
print('z=%f' % zred)
# Out:
# z=0.517862

# %%
fig = plt.figure(figsize=(10,5))
sub = fig.add_subplot(111)
sub.plot(spectra.wave['b'], spectra.flux['b'][igal])
sub.plot(spectra.wave['r'], spectra.flux['r'][igal])
sub.plot(spectra.wave['z'], spectra.flux['z'][igal])
sub.set_xlim(spectra.wave['b'].min(), spectra.wave['z'].max())
sub.set_ylim(0, 5)
# Out:
# (0.0, 5.0)

# %%
# declare prior
priors = Infer.load_priors([
    Infer.UniformPrior(9., 12, label='sed'),
    Infer.FlatDirichletPrior(4, label='sed'),
    Infer.UniformPrior(np.array([6.9e-5, 6.9e-5, 0., 0., -2.2]), np.array([7.3e-3, 7.3e-3, 3., 4., 0.4]), label='sed'),
    Infer.UniformPrior(np.array([0.9, 0.9, 0.9]), np.array([1.1, 1.1, 1.1]), label='flux_calib') # flux calibration variables
    ])

# declare model
m_nmf = Models.NMF(burst=False, emulator=False)

# declare flux calibration
fluxcalib = FluxCalib.constant_flux_DESI_arms
# Out:
# input parameters : logmstar, beta1_sfh, beta2_sfh, beta3_sfh, beta4_sfh, gamma1_zh, gamma2_zh, dust1, dust2, dust_index

# %%
desi_mcmc = Infer.desiMCMC(
    model=m_nmf,
    flux_calib=fluxcalib,
    prior=priors
)

# %%
mcmc = desi_mcmc.run(
    wave_obs=[spectra.wave['b'], spectra.wave['r'], spectra.wave['z']],
    flux_obs=[spectra.flux['b'][igal], spectra.flux['r'][igal], spectra.flux['z'][igal]],
    flux_ivar_obs=[spectra.ivar['b'][igal], spectra.ivar['r'][igal], spectra.ivar['z'][igal]],
    zred=zred,
    sampler='zeus',
    nwalkers=100,
    burnin=100,
    opt_maxiter=10000,
    niter=100,
    debug=True)
# Out:
# --- initializing the walkers ---
# Initialising ensemble of 100 walkers...
# initial theta = [11.00307485086198, 0.6035551968621478, 0.4336804703248759, 0.48712548036092085, 0.006835531856188159, 7.05270130442877e-05, 0.9936957642709082, 0.49090357207225777, -1.503388896861805, 0.9000000158099244, 1.0374547542651547, 1.0184351258866835]
# log Posterior(theta0) = -4517.982706
# --- running MCMC ---
# Sampling progress :   0%|          | 0/200 [00:00<?, ?it/s]
# Sampling progress :   0%|          | 1/200 [00:54<3:00:55, 54.55s/it]
# Sampling progress :   1%|          | 2/200 [01:48<2:59:27, 54.38s/it]
# Sampling progress :   2%|▏         | 3/200 [02:50<3:09:34, 57.74s/it]
# Sampling progress :   2%|▏         | 4/200 [03:48<3:09:22, 57.97s/it]
# Sampling progress :   2%|▎         | 5/200 [04:42<3:03:36, 56.49s/it]
# Sampling progress :   3%|▎         | 6/200 [05:43<3:06:55, 57.81s/it]
# Sampling progress :   4%|▎         | 7/200 [06:36<3:01:30, 56.43s/it]
# Sampling progress :   4%|▍         | 8/200 [07:29<2:57:11, 55.37s/it]
# Sampling progress :   4%|▍         | 9/200 [08:26<2:57:24, 55.73s/it]
# Sampling progress :   5%|▌         | 10/200 [09:26<3:00:48, 57.10s/it]
# Sampling progress :   6%|▌         | 11/200 [10:22<2:58:46, 56.76s/it]
# Sampling progress :   6%|▌         | 12/200 [11:20<2:59:09, 57.18s/it]
# Sampling progress :   6%|▋         | 13/200 [12:21<3:02:08, 58.44s/it]
# Sampling progress :   7%|▋         | 14/200 [13:19<3:00:06, 58.10s/it]
# Sampling progress :   8%|▊         | 15/200 [14:20<3:02:12, 59.09s/it]
# Sampling progress :   8%|▊         | 16/200 [15:14<2:55:54, 57.36s/it]
# Sampling progress :   8%|▊         | 17/200 [16:08<2:52:06, 56.43s/it]
# Sampling progress :   9%|▉         | 18/200 [16:58<2:45:43, 54.63s/it]
# Sampling progress :  10%|▉         | 19/200 [17:53<2:44:54, 54.67s/it]
# Sampling progress :  10%|█         | 20/200 [18:41<2:38:15, 52.75s/it]
# Sampling progress :  10%|█         | 21/200 [19:33<2:36:32, 52.47s/it]
# Sampling progress :  11%|█         | 22/200 [20:29<2:38:40, 53.49s/it]
# Sampling progress :  12%|█▏        | 23/200 [21:16<2:32:21, 51.65s/it]
# Sampling progress :  12%|█▏        | 24/200 [22:07<2:30:14, 51.22s/it]
# Sampling progress :  12%|█▎        | 25/200 [22:56<2:27:35, 50.60s/it]
# Sampling progress :  13%|█▎        | 26/200 [23:46<2:26:08, 50.39s/it]
# Sampling progress :  14%|█▎        | 27/200 [24:43<2:31:19, 52.48s/it]
# Sampling progress :  14%|█▍        | 28/200 [25:35<2:29:40, 52.21s/it]
# Sampling progress :  14%|█▍        | 29/200 [26:30<2:31:57, 53.32s/it]
# Sampling progress :  15%|█▌        | 30/200 [27:24<2:31:08, 53.34s/it]
# Sampling progress :  16%|█▌        | 31/200 [28:19<2:31:29, 53.78s/it]
# Sampling progress :  16%|█▌        | 32/200 [29:16<2:33:30, 54.82s/it]
# Sampling progress :  16%|█▋        | 33/200 [30:08<2:30:34, 54.10s/it]
# Sampling progress :  17%|█▋        | 34/200 [31:05<2:31:57, 54.93s/it]
# Sampling progress :  18%|█▊        | 35/200 [32:01<2:31:38, 55.15s/it]
# Sampling progress :  18%|█▊        | 36/200 [32:52<2:27:50, 54.09s/it]
# Sampling progress :  18%|█▊        | 37/200 [33:53<2:32:03, 55.97s/it]
# Sampling progress :  19%|█▉        | 38/200 [34:53<2:34:19, 57.16s/it]
# Sampling progress :  20%|█▉        | 39/200 [35:41<2:26:24, 54.56s/it]
# Sampling progress :  20%|██        | 40/200 [36:31<2:21:55, 53.22s/it]
# Sampling progress :  20%|██        | 41/200 [37:21<2:18:26, 52.24s/it]
# Sampling progress :  21%|██        | 42/200 [38:10<2:14:33, 51.10s/it]
# Sampling progress :  22%|██▏       | 43/200 [39:04<2:16:17, 52.09s/it]
# Sampling progress :  22%|██▏       | 44/200 [39:54<2:13:40, 51.41s/it]
# Sampling progress :  22%|██▎       | 45/200 [40:48<2:15:11, 52.33s/it]
# Sampling progress :  23%|██▎       | 46/200 [41:45<2:17:57, 53.75s/it]
# Sampling progress :  24%|██▎       | 47/200 [42:35<2:14:00, 52.55s/it]
# Sampling progress :  24%|██▍       | 48/200 [43:24<2:10:31, 51.52s/it]
# Sampling progress :  24%|██▍       | 49/200 [44:14<2:08:17, 50.98s/it]
# Sampling progress :  25%|██▌       | 50/200 [44:59<2:02:38, 49.05s/it]
# Sampling progress :  26%|██▌       | 51/200 [45:48<2:01:47, 49.04s/it]
# Sampling progress :  26%|██▌       | 52/200 [46:40<2:03:16, 49.98s/it]
# Sampling progress :  26%|██▋       | 53/200 [47:29<2:01:48, 49.72s/it]
# Sampling progress :  27%|██▋       | 54/200 [48:17<1:59:46, 49.23s/it]
# Sampling progress :  28%|██▊       | 55/200 [49:03<1:56:30, 48.21s/it]
# Sampling progress :  28%|██▊       | 56/200 [50:02<2:03:30, 51.46s/it]
# Sampling progress :  28%|██▊       | 57/200 [51:00<2:07:25, 53.46s/it]
# Sampling progress :  29%|██▉       | 58/200 [51:54<2:07:07, 53.71s/it]
# Sampling progress :  30%|██▉       | 59/200 [52:44<2:03:10, 52.42s/it]

# %%
fig = plt.figure(figsize=(10,5))
sub = fig.add_subplot(111)
sub.plot(spectra.wave['b'], spectra.flux['b'][igal])
sub.plot(spectra.wave['r'], spectra.flux['r'][igal])
sub.plot(spectra.wave['z'], spectra.flux['z'][igal])
sub.plot(mcmc['wavelength_obs'], mcmc['flux_spec_model'], c='k', ls='--')
sub.set_xlim(spectra.wave['b'].min(), spectra.wave['z'].max())
sub.set_ylim(0, 5)
